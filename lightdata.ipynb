# %% [markdown]
# # 1. Light Data

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# %pip install pandas
# %pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("www.dallasopendata.com", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(www.dallasopendata.com,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
# results = client.get("d7e7-envw", limit=10000)
results = client.get(
    "d7e7-envw",
    where="service_request_type LIKE '%Lighting%'",
    limit=100000
)
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
results_df
results_df.to_csv('results_df.csv',index=False)

# %%
results_df
# Out:
#       service_request_number                                    address  \
# 0                26-00090050     3033 PLAYA VISTA DR, DALLAS, TX, 75236
# 1                26-00087961      2675 ANN ARBOR AVE, DALLAS, TX, 75216
# 2                22-00424823           4153 MURAL LN, DALLAS, TX, 75210
# 3                26-00091707  1400 N WESTMORELAND RD, DALLAS, TX, 75211
# 4                24-00492200       3103 CLYDEDALE DR, DALLAS, TX, 75220
# ...                      ...                                        ...
# 17696            25-00134762          4230 S POLK ST, DALLAS, TX, 75224
# 17697            25-00134762          4230 S POLK ST, DALLAS, TX, 75224
# 17698            20-01136860         2248 GAYLORD DR, DALLAS, TX, 75227
# 17699            25-00507819         1024 S TYLER ST, DALLAS, TX, 75208
# 17700            25-00507819         1024 S TYLER ST, DALLAS, TX, 75208
#
#       city_council_district                                  department  \
# ...

# %%
service_light = results_df
service_light.to_csv('results_df.csv',index=False)
service_light
# Out:
#       service_request_number                                    address  \
# 0                26-00090050     3033 PLAYA VISTA DR, DALLAS, TX, 75236
# 1                26-00087961      2675 ANN ARBOR AVE, DALLAS, TX, 75216
# 2                22-00424823           4153 MURAL LN, DALLAS, TX, 75210
# 3                26-00091707  1400 N WESTMORELAND RD, DALLAS, TX, 75211
# 4                24-00492200       3103 CLYDEDALE DR, DALLAS, TX, 75220
# ...                      ...                                        ...
# 17696            25-00134762          4230 S POLK ST, DALLAS, TX, 75224
# 17697            25-00134762          4230 S POLK ST, DALLAS, TX, 75224
# 17698            20-01136860         2248 GAYLORD DR, DALLAS, TX, 75227
# 17699            25-00507819         1024 S TYLER ST, DALLAS, TX, 75208
# 17700            25-00507819         1024 S TYLER ST, DALLAS, TX, 75208
#
#       city_council_district                                  department  \
# ...

# %% [markdown]
# # 2. EDA

# %%
traffic_signs = results_df[
    results_df["service_request_type"] == "Traffic Sign - Maintenance (Other) - TRN"
]

traffic_signs.head()
# Out:
#     service_request_number                                            address  \
# 61             22-00275358    THURSTON DR & EMPIRE CENTRAL, DALLAS, TX, 75235
# 155            22-00275278          GILFORD ST & DENTON DR, DALLAS, TX, 75235
# 222            21-00442771             1200 URBAN LOFTS DR, DALLAS, TX, 75215
# 310            22-00238481  FAWN VALLEY DR & FAWN RIDGE DR, DALLAS, TX, 75224
# 386            21-00442971           3415 CEDAR SPRINGS RD, DALLAS, TX, 75219
#
#     city_council_district                                  department  \
# 61                      2                              Transportation
# 155                     2  Transportation and Public Works Department
# 222                     2  Transportation and Public Works Department
# 310                     4                              Transportation
# 386                    14                              Transportation
#
# ...

# %%
 results_df["service_request_type"].unique()
# Out:
# array(['Dead Animal Pick Up - DAS', 'Water/Wastewater Line Locate - 311',
#        'Code Concern - CCS', 'Barricades - Pickup/Reset/Replace - TPW',
#        'Extra Police Patrol - DPD', 'Parking - Report a Violation - TPW',
#        'Sanitation Roll Cart Maintenance/Delivery - SAN',
#        'Building Permits Violation - DEV',
#        'Street Repair - Routine - TPW', 'Traffic Signal - Flashing - TRN',
#        'Narcotics/Vice Complaint - DPD', 'Street Repair - Routine - PBW',
#        'Complaint/Compliment - 311',
#        'Scooter/Bike Shared Dockless Vehicle - TPW',
#        'Utility Cut/Routine - TPW', 'Animal Bite - DAS',
#        'Alley Repair - Routine - TPW',
#        'Parking - Report a Violation - TRN',
#        'Lid Cover Broken - Routine - TPW',
#        'Traffic Signal - Knockdown - TRN', 'Traffic Sign - New - TRN',
#        'Traffic Signal - Bulb Out/NonConflict Hd Trn VO - TPW',
#        'Inlet/Storm Drain Cleaning - DWU', 'Shopping Carts - PBW',
# ...

# %%
#light_df = results_df['service_request_type']
streetlights = results_df[
    results_df["service_request_type"].str.contains("Light", case=False, na=False)
]
streetlights
# Out:
#      service_request_number                                    address  \
# 81              26-00090050     3033 PLAYA VISTA DR, DALLAS, TX, 75236
# 237             26-00087961      2675 ANN ARBOR AVE, DALLAS, TX, 75216
# 310             22-00424823           4153 MURAL LN, DALLAS, TX, 75210
# 319             26-00091707  1400 N WESTMORELAND RD, DALLAS, TX, 75211
# 355             24-00492200       3103 CLYDEDALE DR, DALLAS, TX, 75220
# ...                     ...                                        ...
# 9247            26-00093132         11432 REEDER RD, DALLAS, TX, 75229
# 9502            26-00094840    6615 LEANING OAKS ST, DALLAS, TX, 75241
# 9820            25-00149428       1813 VIEWCREST DR, DALLAS, TX, 75228
# 9850            26-00090032  8914 N CENTRAL EXPY NB, DALLAS, TX, 75231
# 9923            26-00095643      9470 WHITEHURST DR, DALLAS, TX, 75243
#
#      city_council_district                                  department  \
# ...
